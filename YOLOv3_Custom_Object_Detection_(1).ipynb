# %% [markdown]
# <a href="https://colab.research.google.com/github/RANJITHROSAN17/yolov3/blob/main/YOLOv3_Custom_Object_Detection_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Tue Aug 29 06:48:47 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **1) Clone, configure & compile Darknet**

# %%
# Clone
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15711, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 15711 (delta 78), reused 141 (delta 76), pack-reused 15536
# Receiving objects: 100% (15711/15711), 14.55 MiB | 7.47 MiB/s, done.
# Resolving deltas: 100% (10506/10506), done.

# %%
# Configure
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# Compile
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   946 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1444:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1444 |         char buff[100];
#       |              ^~~~
# ...

# %% [markdown]
# **2) Configure yolov3.cfg file**

# %%
# Make a copy of yolov3.cfg
# !cp cfg/yolov3.cfg /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg

# %%
# Change lines in yolov3.cfg file
# !sed -i 's/batch=1/batch=64/' /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg
# !sed -i 's/max_batches = 500200/max_batches = 2000/' /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg
# !sed -i '610 s@classes=80@classes=2@' /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg
# !sed -i '696 s@classes=80@classes=2@' /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg
# !sed -i '783 s@classes=80@classes=2@' /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg
# !sed -i '603 s@filters=255@filters=21@' /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg
# !sed -i '689 s@filters=255@filters=21@' /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg
# !sed -i '776 s@filters=255@filters=21@' /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg

# %% [markdown]
# **3) Create .names and .data files**

# %%
# !echo -e 'person' > data/obj.names
# !echo -e 'classes= 1\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /content/gdrive/MyDrive/custom_data/backup' > data/obj.data

# %% [markdown]
# **4) Save yolov3_training.cfg and obj.names files in Google drive**

# %%
# !mkdir /content/gdrive/MyDrive/custom_data/yolov3_testing.cfg
# !mkdir /content/gdrive/MyDrive/custom_data/classes.txt
# Out:
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/custom_data/yolov3_testing.cfg’: File exists
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/custom_data/classes.txt’: File exists

# %%
# !cp /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg /content/gdrive/MyDrive/custom_data/yolov3_testing.cfg
# !cp data/obj.names /content/gdrive/MyDrive/custom_data/classes.txt

# %% [markdown]
# **5) Create a folder and unzip image dataset**

# %%
# !mkdir data/obj
# !unzip /content/gdrive/MyDrive/custom_data/zip/images.zip -d data/obj
# Out:
# Archive:  /content/gdrive/MyDrive/custom_data/zip/images.zip
#   inflating: data/obj/images/frame_0000.jpg
#   inflating: data/obj/images/frame_0000.txt
#   inflating: data/obj/images/frame_0010.jpg
#   inflating: data/obj/images/frame_0010.txt
#   inflating: data/obj/images/frame_0020.jpg
#   inflating: data/obj/images/frame_0020.txt
#   inflating: data/obj/images/frame_0030.jpg
#   inflating: data/obj/images/frame_0030.txt
#   inflating: data/obj/images/frame_0040.jpg
#   inflating: data/obj/images/frame_0040.txt
#   inflating: data/obj/images/frame_0050.jpg
#   inflating: data/obj/images/frame_0050.txt
#   inflating: data/obj/images/frame_0060.jpg
#   inflating: data/obj/images/frame_0060.txt
#   inflating: data/obj/images/frame_0070.jpg
#   inflating: data/obj/images/frame_0070.txt
#   inflating: data/obj/images/frame_0080.jpg
#   inflating: data/obj/images/frame_0080.txt
#   inflating: data/obj/images/frame_0090.jpg
#   inflating: data/obj/images/frame_0090.txt
# ...

# %% [markdown]
# **6) Create train.txt file**

# %%
import glob
images_list = glob.glob("/content/darknet/data/obj/images/*.jpg")
with open("data/train.txt", "w") as f:
    f.write("\n".join(images_list))

# %%
# !cp /content/gdrive/MyDrive/custom_data/train.txt -d data/

# %% [markdown]
# **7) Download pre-trained weights for the convolutional layers file**

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2023-08-29 06:54:22--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  4.45MB/s    in 19s
#
# 2023-08-29 06:54:42 (8.04 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# **8) Start training**

# %%
# !./darknet detector train data/obj.data /content/gdrive/MyDrive/custom_data/cfg/yolov3-custom.cfg darknet53.conv.74 -dont_show
# Uncomment below and comment above to re-start your training from last saved weights
#!./darknet detector train data/obj.data cfg/yolov3_training.cfg /mydrive/yolov3/yolov3_training_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# 1720/2000: loss=0.1 hours left=0.5
#  1720: 0.066321, 0.054400 avg loss, 0.000100 rate, 4.057492 seconds, 110080 images, 0.522177 hours left
# Resizing, random_coef = 1.40
#
#  576 x 576
#  try to allocate additional workspace_size = 286.95 MB
#  CUDA allocate done!
# Loaded: 0.000057 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.002042, iou_loss = 0.000000, total_loss = 0.002042
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.871620), count: 4, class_loss = 0.062066, iou_loss = 0.128801, total_loss = 0.190867
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000846, iou_loss = 0.000000, total_loss = 0.000846
#  total_bbox = 136586, rewritten_bbox = 0.000000 %
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
